# %% [markdown]
# <a href="https://colab.research.google.com/github/Firefox-097/Steganography/blob/main/Experiment2_DatasetSelection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
datasets = {
    "Current Kaggle Dataset": {
        "Size": "24000 images",
        "Status": "Tested",
        "Result": "Poor generalization"
    },
    "ALASKA2": {
        "Size": "305000 images",
        "Status": "Very Large",
        "Result": "Requires subset"
    },
    "BOSSBase": {
        "Size": "10000 images",
        "Status": "Research Benchmark",
        "Result": "Candidate"
    },
    "StegoAppDB": {
        "Size": "Large",
        "Status": "Research Dataset",
        "Result": "Candidate"
    }
}

for name, info in datasets.items():
    print(f"\n{name}")
    for k, v in info.items():
        print(f"{k}: {v}")
# Out:
# Current Kaggle Dataset
# Size: 24000 images
# Status: Tested
# Result: Poor generalization
#
# ALASKA2
# Size: 305000 images
# Status: Very Large
# Result: Requires subset
#
# BOSSBase
# Size: 10000 images
# Status: Research Benchmark
# Result: Candidate
#
# StegoAppDB
# Size: Large
# Status: Research Dataset
# Result: Candidate
